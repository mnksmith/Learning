# %%
import pandas as pd
list_keys = ['Country', 'Total']
list_values = [['United States', 'Soviet Union', 'United Kingdom'], [1118, 473, 273]]

# %%
# Zip the 2 lists together into one list of (key,value) tuples: zipped
zipped = list(zip(list_keys,list_values))

# Inspect the list using print()
print(zipped)

# Build a dictionary with the zipped list: data
data = dict(zipped)

# Build and inspect a DataFrame from the dictionary: df
df = pd.DataFrame(data)
print(df)
# Out:
# [('Country', ['United States', 'Soviet Union', 'United Kingdom']), ('Total', [1118, 473, 273])]
#           Country  Total
# 0   United States   1118
# 1    Soviet Union    473
# 2  United Kingdom    273

# %%
from urllib.request import urlretrieve
url = 'https://assets.datacamp.com/production/course_1639/datasets/weather_data_austin_2010.csv'
urlretrieve(url, 'dc_austin2010.csv')
df = pd.read_csv('dc_austin2010.csv')

# %%
import matplotlib.pyplot as plt
# Create a plot with color='red'
df_slim = df.loc[:800,:]
df_slim.Temperature.plot(color='red')

# Add a title
plt.title('Temperature in Austin')

# Specify the x-axis label
plt.xlabel('Hours since midnight August 1, 2010')

# Specify the y-axis label
plt.ylabel('Temperature (degrees F)')

# Display the plot
plt.show()

# %%
# Plot all columns (default)
df_slim.plot()
plt.show()

# Plot all columns as subplots
df_slim.plot(subplots=True)
plt.show()

# Plot just the Dew Point data
column_list1 = ['DewPoint']
df_slim[column_list1].plot()
plt.show()

# Plot the Dew Point and Temperature data, but not the Pressure data
column_list2 = ['Temperature','DewPoint']
df_slim[column_list2].plot()
plt.show()

# %%
url = 'https://assets.datacamp.com/production/course_1639/datasets/auto-mpg.csv'
urlretrieve(url, 'dc_auto-mpg.csv')
mpg = pd.read_csv('dc_auto-mpg.csv')
mpg['weight'] = pd.to_numeric(mpg['weight'], errors='coerce')

# %%
mpg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 9 columns):
# mpg       392 non-null float64
# cyl       392 non-null int64
# displ     392 non-null float64
# hp        392 non-null int64
# weight    392 non-null int64
# accel     392 non-null float64
# yr        392 non-null int64
# origin    392 non-null object
# name      392 non-null object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 27.6+ KB

# %%
# Generate a scatter plot
weights = mpg['weight']/100
mpg.plot(kind='scatter', x='hp', y='mpg', s=weights)

# Add the title
plt.title('Fuel efficiency vs Horse-power')

# Add the x-axis label
plt.xlabel('Horse-power')

# Add the y-axis label
plt.ylabel('Fuel efficiency (mpg)')

# Display the plot
plt.show()

# %%
cols = ['weight','mpg']

# Generate the box plots
mpg[cols].plot(kind='box',subplots=True)

plt.show()

# %%
tips = pd.read_csv('dc_tips.csv')
tips['fraction'] = tips['tip']/tips['total_bill']
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  fraction
# 0       16.99  1.01  Female     No  Sun  Dinner     2  0.059447
# 1       10.34  1.66    Male     No  Sun  Dinner     3  0.160542
# 2       21.01  3.50    Male     No  Sun  Dinner     3  0.166587
# 3       23.68  3.31    Male     No  Sun  Dinner     2  0.139780
# 4       24.59  3.61  Female     No  Sun  Dinner     4  0.146808

# %%
# This formats the plots such that they appear on separate rows
fig, axes = plt.subplots(nrows=2, ncols=1)

# Plot the PDF
tips.fraction.plot(ax=axes[0], kind='hist', normed=True, bins=30, range=(0,.3))

# Plot the CDF
tips.fraction.plot(ax=axes[1], kind='hist', cumulative=True, normed=True, bins=30, range=(0,.3))
plt.show()

# %%
url = 'https://assets.datacamp.com/production/course_1639/datasets/percent-bachelors-degrees-women-usa.csv'
urlretrieve(url, 'dc_bach_women.csv')
bach = pd.read_csv('dc_bach_women.csv')
bach = bach.set_index('Year')

# %%
print(bach.Engineering.min())
print(bach.Engineering.max())

# Construct the mean percentage per year: mean
mean = bach.mean(axis='columns')

# Plot the average percentage per year
mean.plot()

# Display the plot
plt.show()
# Out:
# 0.8
# 19.0

# %%
url = 'https://assets.datacamp.com/production/course_1639/datasets/life_expectancy_at_birth.csv'
urlretrieve(url,'dc_gapminder2.csv')
gapminder = pd.read_csv('dc_gapminder2.csv')
gapminder.head()
# Out:
#    Unnamed: 0        Life expectancy   1800   1801   1802   1803   1804  \
# 0           0               Abkhazia    NaN    NaN    NaN    NaN    NaN
# 1           1            Afghanistan  28.21  28.20  28.19  28.18  28.17
# 2           2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN
# 3           3                Albania  35.40  35.40  35.40  35.40  35.40
# 4           4                Algeria  28.82  28.82  28.82  28.82  28.82
#
#     1805   1806   1807  ...    2007  2008  2009  2010  2011  2012  2013  2014  \
# 0    NaN    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.16  28.15  28.14  ...    52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9
# 2    NaN    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  35.40  ...    76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9
# 4  28.82  28.82  28.82  ...    75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3
#
#    2015   2016
# 0   NaN    NaN
# 1  53.8  52.72
# ...

# %%
print(gapminder['2015'].count())

# Print the 5th and 95th percentiles
print(gapminder.quantile([0.05,0.95]))

# Generate a box plot
years = ['1800','1850','1900','1950','2000']
gapminder[years].plot(kind='box')
plt.show()
# Out:
# 208
#       Unnamed: 0   1800   1801   1802  1803  1804   1805   1806   1807  1808  \
# 0.05       12.95  25.40  25.30  25.20  25.2  25.2  25.40  25.40  25.40  25.3
# 0.95      246.05  37.92  37.35  38.37  38.0  38.3  38.37  38.37  38.37  38.0
#
#        ...      2007   2008    2009    2010   2011    2012    2013   2014  \
# 0.05   ...     53.07  53.60  54.235  54.935  55.97  56.335  56.705  56.87
# 0.95   ...     80.73  80.93  81.200  81.365  81.60  81.665  81.830  82.00
#
#         2015     2016
# 0.05  57.855  59.2555
# 0.95  82.100  82.1650
#
# [2 rows x 218 columns]

# %%
# Compute the global mean and global standard deviation: global_mean, global_std
global_mean = mpg.mean()
global_std = mpg.std()

# Filter the US population from the origin column: us
us = mpg[mpg['origin']=='US']

# Compute the US mean and US standard deviation: us_mean, us_std
us_mean = us.mean()
us_std = us.std()

# Print the differences
print(us_mean - global_mean)
print(us_std - global_std)
# Out:
# mpg        -3.412449
# cyl         0.805612
# displ      53.100255
# hp         14.579592
# weight    394.905612
# accel      -0.551122
# yr         -0.387755
# dtype: float64
# mpg       -1.364623
# cyl       -0.049788
# displ     -6.267657
# hp         1.406630
# weight   -54.055870
# accel     -0.022844
# yr        -0.023369
# dtype: float64

# %% [markdown]
# # Time series

# %%
time_format = '%Y-%m-%d %H:%M'
df['Date'] = pd.to_datetime(df['Date'], format=time_format)
df =df.set_index('Date')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8759 entries, 2010-01-01 00:00:00 to 2010-12-31 23:00:00
# Data columns (total 3 columns):
# Temperature    8759 non-null float64
# DewPoint       8759 non-null float64
# Pressure       8759 non-null float64
# dtypes: float64(3)
# memory usage: 273.7 KB

# %%
# Extract the hour from 9pm to 10pm on '2010-10-11': ts1
ts1 = df.loc['2010-10-11 21:00:00':'2010-10-11 22:00:00']

# Extract '2010-07-04' from ts0: ts2
ts2 = df.loc['2010-07-04']

# Extract data from '2010-12-15' to '2010-12-31': ts3
ts3 = df.loc['2010-12-15':'2010-12-31']

# %%
# Downsample to 6 hour data and aggregate by mean: df1
df1 = df['Temperature'].resample('6h').mean()
print(df1.head())

# Downsample to daily data and count the number of data points: df2
df2 = df['Temperature'].resample('D').count()
print(df2.head())
# Out:
# Date
# 2010-01-01 00:00:00    44.200000
# 2010-01-01 06:00:00    45.933333
# 2010-01-01 12:00:00    57.766667
# 2010-01-01 18:00:00    49.450000
# 2010-01-02 00:00:00    44.516667
# Freq: 6H, Name: Temperature, dtype: float64
# Date
# 2010-01-01    24
# 2010-01-02    24
# 2010-01-03    24
# 2010-01-04    24
# 2010-01-05    24
# Freq: D, Name: Temperature, dtype: int64

# %%
# Extract temperature data for August: august
august = df.loc['2010-August'].Temperature

# Downsample to obtain only the daily highest temperatures in August: august_highs
august_highs = august.resample('D').max()
print(august_highs)

# Extract temperature data for February: february
february = df.loc['2010-02'].Temperature

# Downsample to obtain the daily lowest temperatures in February: february_lows
february_lows = february.resample('D').min()
print(february_lows)
# Out:
# Date
# 2010-08-01    95.0
# 2010-08-02    95.0
# 2010-08-03    95.1
# 2010-08-04    95.1
# 2010-08-05    95.1
# 2010-08-06    95.2
# 2010-08-07    95.3
# 2010-08-08    95.2
# 2010-08-09    95.2
# 2010-08-10    95.1
# 2010-08-11    95.0
# 2010-08-12    94.9
# 2010-08-13    95.0
# 2010-08-14    94.9
# 2010-08-15    94.7
# 2010-08-16    94.7
# 2010-08-17    94.8
# 2010-08-18    94.8
# 2010-08-19    94.8
# 2010-08-20    94.8
# 2010-08-21    94.7
# 2010-08-22    94.6
# 2010-08-23    94.5
# 2010-08-24    94.3
# 2010-08-25    94.1
# 2010-08-26    94.0
# 2010-08-27    93.7
# 2010-08-28    93.5
# 2010-08-29    93.3
# 2010-08-30    93.3
# 2010-08-31    93.1
# Freq: D, Name: Temperature, dtype: float64
# Date
# 2010-02-01    43.8
# 2010-02-02    44.3
# 2010-02-03    44.6
# 2010-02-04    44.5
# 2010-02-05    44.3
# 2010-02-06    44.1
# 2010-02-07    44.3
# 2010-02-08    44.7
# 2010-02-09    44.7
# 2010-02-10    44.9
# 2010-02-11    45.2
# 2010-02-12    45.5
# 2010-02-13    46.0
# ...

# %%
# Extract data from 2010-Aug-01 to 2010-Aug-15: unsmoothed
unsmoothed = df.loc['2010-Aug-01':'2010-Aug-15'].Temperature

# Apply a rolling mean with a 24 hour window: smoothed
smoothed = unsmoothed.rolling(window=24).mean()

# Create a new DataFrame with columns smoothed and unsmoothed: august
august = pd.DataFrame({'smoothed':smoothed, 'unsmoothed':unsmoothed})

# Plot both smoothed and unsmoothed data using august.plot().
august.plot()
plt.show()

# %%
# Extract the August 2010 data: august
august = df['Temperature']['2010-Aug']

# Resample to daily data, aggregating by max: daily_highs
daily_highs = august.resample('D').max()

# Use a rolling 7-day window with method chaining to smooth the daily high temperatures in August
daily_highs_smoothed = daily_highs.rolling(window=7).mean()
print(daily_highs_smoothed)
# Out:
# Date
# 2010-08-01          NaN
# 2010-08-02          NaN
# 2010-08-03          NaN
# 2010-08-04          NaN
# 2010-08-05          NaN
# 2010-08-06          NaN
# 2010-08-07    95.114286
# 2010-08-08    95.142857
# 2010-08-09    95.171429
# 2010-08-10    95.171429
# 2010-08-11    95.157143
# 2010-08-12    95.128571
# 2010-08-13    95.100000
# 2010-08-14    95.042857
# 2010-08-15    94.971429
# 2010-08-16    94.900000
# 2010-08-17    94.857143
# 2010-08-18    94.828571
# 2010-08-19    94.814286
# 2010-08-20    94.785714
# 2010-08-21    94.757143
# 2010-08-22    94.742857
# 2010-08-23    94.714286
# 2010-08-24    94.642857
# 2010-08-25    94.542857
# 2010-08-26    94.428571
# 2010-08-27    94.271429
# 2010-08-28    94.100000
# 2010-08-29    93.914286
# 2010-08-30    93.742857
# 2010-08-31    93.571429
# Freq: D, Name: Temperature, dtype: float64

# %%
# Plot the summer data
df.Temperature['2010-Jun':'2010-Aug'].plot()
plt.show()
plt.clf()

# Plot the one week data
df.Temperature['2010-06-10':'2010-06-17'].plot()
plt.show()
plt.clf()

# %%
url = 'https://assets.datacamp.com/production/course_1639/datasets/austin_airport_departure_data_2015_july.csv'
urlretrieve(url,'dc_airport.csv')
airport = pd.read_csv('dc_airport.csv',header=10)
time_format = '%m/%d/%Y'
airport['Date (MM/DD/YYYY)'] = pd.to_datetime(airport['Date (MM/DD/YYYY)'], format=time_format)
airport = airport.set_index('Date (MM/DD/YYYY)')

# %%
airport.head()
# Out:
#                     Carrier Code  Flight Number Tail Number  \
# Date (MM/DD/YYYY)
# 2015-07-01                    WN          103.0      N8607M
# 2015-07-01                    WN          144.0      N8609A
# 2015-07-01                    WN          178.0      N646SW
# 2015-07-01                    WN          232.0      N204WN
# 2015-07-01                    WN          238.0      N233LV
#
#                   Destination Airport  Scheduled Departure Time  \
# Date (MM/DD/YYYY)
# 2015-07-01                         MDW                    06:30
# 2015-07-01                         SAN                    20:55
# 2015-07-01                         ELP                    20:30
# 2015-07-01                         ATL                    05:45
# 2015-07-01                         DAL                    12:30
#
#                   Actual Departure Time  Scheduled Elapsed Time(Minutes)  \
# Date (MM/DD/YYYY)
# 2015-07-01                        06:52                            165.0
# ...

# %%
# Strip extra whitespace from the column names: df.columns
airport.columns = airport.columns.str.strip()

# Extract data for which the destination airport is Dallas: dallas
dallas = airport['Destination Airport'].str.contains('DAL')

# Compute the total number of Dallas departures each day: daily_departures
daily_departures = dallas.resample('D').sum()

# Generate the summary statistics for daily Dallas departures: stats
stats = daily_departures.describe()

# %%
print(stats)
# Out:
# count    31.000000
# mean      9.322581
# std       1.989759
# min       3.000000
# 25%       9.500000
# 50%      10.000000
# 75%      10.000000
# max      11.000000
# dtype: float64

# %%
url = 'https://assets.datacamp.com/production/course_1639/datasets/austin_airport_departure_data_2015_july.csv'
urlretrieve(url,'dc_airport.csv')
airport = pd.read_csv('dc_airport.csv',header=10)
# Strip extra whitespace from the column names: df.columns
airport.columns = airport.columns.str.strip()

# %%
# Build a Boolean mask to filter out all the 'LAX' departure flights: mask
mask = airport['Destination Airport'] == 'LAX'

# Use the mask to subset the data: la
la = airport[mask]

# Combine two columns of data to create a datetime series: times_tz_none 
times_tz_none = pd.to_datetime( la['Date (MM/DD/YYYY)'] + ' ' + la['Wheels-off Time'] )

# Localize the time to US/Central: times_tz_central
times_tz_central = times_tz_none.dt.tz_localize('US/Central')

# Convert the datetimes from US/Central to US/Pacific
times_tz_pacific = times_tz_central.dt.tz_convert('US/Pacific')

# %%
print(times_tz_central.head())
print(times_tz_pacific.head())
# Out:
# 33    2015-07-01 05:43:00-05:00
# 55    2015-07-01 16:27:00-05:00
# 91    2015-07-02 05:47:00-05:00
# 113   2015-07-02 16:23:00-05:00
# 134   2015-07-03 05:30:00-05:00
# dtype: datetime64[ns, US/Central]
# 33    2015-07-01 03:43:00-07:00
# 55    2015-07-01 14:27:00-07:00
# 91    2015-07-02 03:47:00-07:00
# 113   2015-07-02 14:23:00-07:00
# 134   2015-07-03 03:30:00-07:00
# dtype: datetime64[ns, US/Pacific]

# %% [markdown]
# # Cleaning/Tidying data

# %%
url = 'https://assets.datacamp.com/production/course_1639/datasets/NOAA_QCLCD_2011_hourly_13904.txt'
urlretrieve(url, 'dc_climate_normals.txt')
climate = pd.read_csv('dc_climate_normals.txt', header=None)
column_labels = 'Wban,date,Time,StationType,sky_condition,sky_conditionFlag,visibility,visibilityFlag,wx_and_obst_to_vision,wx_and_obst_to_visionFlag,dry_bulb_faren,dry_bulb_farenFlag,dry_bulb_cel,dry_bulb_celFlag,wet_bulb_faren,wet_bulb_farenFlag,wet_bulb_cel,wet_bulb_celFlag,dew_point_faren,dew_point_farenFlag,dew_point_cel,dew_point_celFlag,relative_humidity,relative_humidityFlag,wind_speed,wind_speedFlag,wind_direction,wind_directionFlag,value_for_wind_character,value_for_wind_characterFlag,station_pressure,station_pressureFlag,pressure_tendency,pressure_tendencyFlag,presschange,presschangeFlag,sea_level_pressure,sea_level_pressureFlag,record_type,hourly_precip,hourly_precipFlag,altimeter,altimeterFlag,junk'

# %%
# Split on the comma to create a list: column_labels_list
column_labels_list = column_labels.split(',')

# Assign the new column labels to the DataFrame: df.columns
climate.columns = column_labels_list

list_to_drop = ['sky_conditionFlag',
 'visibilityFlag',
 'wx_and_obst_to_vision',
 'wx_and_obst_to_visionFlag',
 'dry_bulb_farenFlag',
 'dry_bulb_celFlag',
 'wet_bulb_farenFlag',
 'wet_bulb_celFlag',
 'dew_point_farenFlag',
 'dew_point_celFlag',
 'relative_humidityFlag',
 'wind_speedFlag',
 'wind_directionFlag',
 'value_for_wind_character',
 'value_for_wind_characterFlag',
 'station_pressureFlag',
 'pressure_tendencyFlag',
 'pressure_tendency',
 'presschange',
 'presschangeFlag',
 'sea_level_pressureFlag',
 'hourly_precip',
 'hourly_precipFlag',
 'altimeter',
 'record_type',
 'altimeterFlag',
 'junk']

# Remove the appropriate columns: df_dropped
climate_dropped = climate.drop(list_to_drop, axis='columns')

# Print the output of df_dropped.head()
print(climate_dropped.head())
# Out:
#     Wban      date  Time  StationType sky_condition visibility dry_bulb_faren  \
# 0  13904  20110101    53           12        OVC045      10.00             51
# 1  13904  20110101   153           12        OVC049      10.00             51
# 2  13904  20110101   253           12        OVC060      10.00             51
# 3  13904  20110101   353           12        OVC065      10.00             50
# 4  13904  20110101   453           12        BKN070      10.00             50
#
#   dry_bulb_cel wet_bulb_faren wet_bulb_cel dew_point_faren dew_point_cel  \
# 0         10.6             38          3.1              15          -9.4
# 1         10.6             37          3.0              14         -10.0
# 2         10.6             37          2.9              13         -10.6
# 3         10.0             38          3.1              17          -8.3
# 4         10.0             37          2.8              15          -9.4
#
# ...

# %%
# Convert the date column to string: df_dropped['date']
climate_dropped['date'] = climate_dropped['date'].astype(str)

# Pad leading zeros to the Time column: df_dropped['Time']
climate_dropped['Time'] = climate_dropped['Time'].apply(lambda x:'{:0>4}'.format(x))

# Concatenate the new date and Time columns: date_string
date_string = climate_dropped['date'] + climate_dropped['Time']

# Convert the date_string Series to datetime: date_times
date_times = pd.to_datetime(date_string, format='%Y%m%d%H%M')

# Set the index to be the new date_times container: df_clean
climate_clean = climate_dropped.set_index(date_times)

# Print the output of df_clean.head()
print(climate_clean.head())
# Out:
#                       Wban      date  Time  StationType sky_condition  \
# 2011-01-01 00:53:00  13904  20110101  0053           12        OVC045
# 2011-01-01 01:53:00  13904  20110101  0153           12        OVC049
# 2011-01-01 02:53:00  13904  20110101  0253           12        OVC060
# 2011-01-01 03:53:00  13904  20110101  0353           12        OVC065
# 2011-01-01 04:53:00  13904  20110101  0453           12        BKN070
#
#                     visibility dry_bulb_faren dry_bulb_cel wet_bulb_faren  \
# 2011-01-01 00:53:00      10.00             51         10.6             38
# 2011-01-01 01:53:00      10.00             51         10.6             37
# 2011-01-01 02:53:00      10.00             51         10.6             37
# 2011-01-01 03:53:00      10.00             50         10.0             38
# 2011-01-01 04:53:00      10.00             50         10.0             37
#
#                     wet_bulb_cel dew_point_faren dew_point_cel  \
# ...

# %%
# Print the dry_bulb_faren temperature between 8 AM and 9 AM on June 20, 2011
print(climate_clean.loc['2011-06-20 08:00':'2011-06-20 09:00', 'dry_bulb_faren'])

# Convert the dry_bulb_faren column to numeric values: df_clean['dry_bulb_faren']
climate_clean['dry_bulb_faren'] = pd.to_numeric(climate_clean['dry_bulb_faren'], errors='coerce')

# Print the transformed dry_bulb_faren temperature between 8 AM and 9 AM on June 20, 2011
print(climate_clean.loc['2011-06-20 08:00':'2011-06-20 09:00', 'dry_bulb_faren'])

# Convert the wind_speed and dew_point_faren columns to numeric values
climate_clean['wind_speed'] = pd.to_numeric(climate_clean['wind_speed'], errors='coerce')
climate_clean['dew_point_faren'] = pd.to_numeric(climate_clean['dew_point_faren'], errors='coerce')
climate_clean['visibility'] = pd.to_numeric(climate_clean['visibility'], errors='coerce')
# Out:
# 2011-06-20 08:27:00     NaN
# 2011-06-20 08:28:00     NaN
# 2011-06-20 08:29:00     NaN
# 2011-06-20 08:30:00     NaN
# 2011-06-20 08:31:00     NaN
# 2011-06-20 08:32:00     NaN
# 2011-06-20 08:33:00     NaN
# 2011-06-20 08:34:00     NaN
# 2011-06-20 08:35:00     NaN
# 2011-06-20 08:53:00    83.0
# Name: dry_bulb_faren, dtype: float64
# 2011-06-20 08:27:00     NaN
# 2011-06-20 08:28:00     NaN
# 2011-06-20 08:29:00     NaN
# 2011-06-20 08:30:00     NaN
# 2011-06-20 08:31:00     NaN
# 2011-06-20 08:32:00     NaN
# 2011-06-20 08:33:00     NaN
# 2011-06-20 08:34:00     NaN
# 2011-06-20 08:35:00     NaN
# 2011-06-20 08:53:00    83.0
# Name: dry_bulb_faren, dtype: float64

# %% [markdown]
# # Statistical analysis

# %%
# Print the median of the dry_bulb_faren column
print(climate_clean['dry_bulb_faren'].median())

# Print the median of the dry_bulb_faren column for the time range '2011-Apr':'2011-Jun'
print(climate_clean.loc['2011-Apr':'2011-Jun', 'dry_bulb_faren'].median())

# Print the median of the dry_bulb_faren column for the month of January
print(climate_clean.loc['2011-Jan', 'dry_bulb_faren'].median())
# Out:
# 72.0
# 78.0
# 48.0

# %%
# Downsample df_clean by day and aggregate by mean: daily_mean_2011
daily_mean_2011 = climate_clean.resample('D').mean()

# Extract the dry_bulb_faren column from daily_mean_2011 using .values: daily_temp_2011
daily_temp_2011 = daily_mean_2011['dry_bulb_faren'].values

# df is from earlier--temperature data from 2010
daily_climate = df.resample('D').mean()

# Extract the Temperature column from daily_climate using .reset_index(): daily_temp_climate
daily_temp_climate = daily_climate.reset_index()['Temperature']

# Compute the difference between the two arrays and print the mean difference
difference = daily_temp_2011 - daily_temp_climate
print(difference.mean())
# Out:
# 1.3301831870056482

# %%
# Select days that are sunny: sunny
sunny = climate_clean.loc[climate_clean['sky_condition']=='CLR']

# Select days that are overcast: overcast
overcast = climate_clean.loc[climate_clean['sky_condition'].str.contains('OVC')]

# Resample sunny and overcast, aggregating by maximum daily temperature
sunny_daily_max = sunny.resample('D').max()
overcast_daily_max = overcast.resample('D').max()

# Print the difference between the mean of sunny_daily_max and overcast_daily_max
print(sunny_daily_max.mean() - overcast_daily_max.mean())
# Out:
# Wban               0.000000
# StationType        0.000000
# dry_bulb_faren     6.504304
# dew_point_faren   -4.339286
# wind_speed        -3.246062
# dtype: float64

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Select the visibility and dry_bulb_faren columns and resample them: weekly_mean
weekly_mean = climate_clean.loc[:,['visibility', 'dry_bulb_faren']].resample('W').mean()

# Print the output of weekly_mean.corr()
print(weekly_mean.corr())

# Plot weekly_mean with subplots=True
weekly_mean.plot(subplots=True)
plt.show()
# Out:
#                 visibility  dry_bulb_faren
# visibility        1.000000        0.490328
# dry_bulb_faren    0.490328        1.000000

# %%
# Create a Boolean Series for sunny days: sunny
sunny = climate_clean['sky_condition']=='CLR'

# Resample the Boolean Series by day and compute the sum: sunny_hours
sunny_hours = sunny.resample('D').sum()

# Resample the Boolean Series by day and compute the count: total_hours
total_hours = sunny.resample('D').count()

# Divide sunny_hours by total_hours: sunny_fraction
sunny_fraction = sunny_hours / total_hours

# Make a box plot of sunny_fraction
sunny_fraction.plot(kind='box')
plt.show()

# %%
# Resample dew_point_faren and dry_bulb_faren by Month, aggregating the maximum values: monthly_max
monthly_max = climate_clean[['dew_point_faren','dry_bulb_faren']].resample('M').max()

# Generate a histogram with bins=8, alpha=0.5, subplots=True
monthly_max.plot(kind='hist', bins=8, alpha=0.5, subplots=True)

# Show the plot
plt.show()

# %%
# Extract the maximum temperature in August 2010 from df_climate: august_max
august_max = df.loc['2010-08','Temperature'].max()
print(august_max)

# Resample August 2011 temps in df_clean by day & aggregate the max value: august_2011
august_2011 = climate_clean.loc['2011-08', 'dry_bulb_faren'].resample('D').max()


# Filter for days in august_2011 where the value exceeds august_max: august_2011_high

august_2011_high = august_2011[august_2011>august_max]

# Construct a CDF of august_2011_high
august_2011_high.plot(kind='hist', cumulative=True, normed=True, bins=25)

# Display the plot
plt.show()
# Out:
# 95.3
